# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/CVML/blob/master/Image_Read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

#import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #This programs is to read the image using opencv

# %%
print(cv2.__version__)
# Out:
# 4.1.2

# %%
data =cv2.imread("/content/1.png")

# %%
print(data.shape[0])
print(data.shape[1])
print(data.shape[2])
# Out:
# 881
# 1566
# 3

# %%
plt.imshow(data)
